# %% [markdown]
# ## Insurance charges prediction using multiple linear regression

# %%
# Insurance charges prediction using multiple linear regression

from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1023, 758)
        Form.setStyleSheet("background-color: rgb(255, 255, 255);")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(0, 0, 1051, 131))
        self.label.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:1, x2:0, y2:0, stop:0 rgba(49, 0, 74, 255), stop:0.079602 rgba(80, 8, 73, 255), stop:0.427861 rgba(255, 255, 255, 255), stop:0.572139 rgba(254, 254, 254, 255), stop:0.776119 rgba(114, 58, 101, 255), stop:0.875622 rgba(60, 3, 45, 255), stop:0.920398 rgba(46, 6, 36, 255), stop:1 rgba(55, 0, 43, 255));\n"
"color: rgb(97, 14, 79);\n"
"font: 63 20pt \"Bookman Old Style\";")
        self.label.setAlignment(QtCore.Qt.AlignCenter)
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(120, 210, 121, 31))
        self.label_2.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);\n"
"")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(120, 260, 101, 31))
        self.label_3.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);\n"
"\n"
"")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(120, 320, 91, 31))
        self.label_4.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);\n"
"")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(120, 370, 111, 51))
        self.label_5.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);\n"
"\n"
"")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(120, 440, 111, 41))
        self.label_6.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);\n"
"")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(120, 500, 121, 41))
        self.label_7.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);\n"
"")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(210, 630, 241, 71))
        self.label_8.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);\n"
"")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(370, 150, 311, 41))
        font = QtGui.QFont()
        font.setFamily("Stencil")
        font.setPointSize(12)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.label_9.setFont(font)
        self.label_9.setStyleSheet("\n"
"font: 12pt \"Stencil\";\n"
"color: rgb(86, 9, 82);\n"
"")
        self.label_9.setTextFormat(QtCore.Qt.AutoText)
        self.label_9.setAlignment(QtCore.Qt.AlignCenter)
        self.label_9.setWordWrap(False)
        self.label_9.setObjectName("label_9")
        self.age_ed = QtWidgets.QLineEdit(Form)
        self.age_ed.setGeometry(QtCore.QRect(360, 210, 231, 31))
        self.age_ed.setStyleSheet("background-color: rgb(229, 229, 229);\n"
"font: 11pt \"Times New Roman\";\n"
"color: rgb(6, 6, 6);")
        self.age_ed.setObjectName("age_ed")
        self.sex_ed = QtWidgets.QLineEdit(Form)
        self.sex_ed.setGeometry(QtCore.QRect(360, 270, 231, 31))
        self.sex_ed.setStyleSheet("background-color: rgb(229, 229, 229);\n"
"font: 11pt \"Times New Roman\";\n"
"color: rgb(6, 6, 6);")
        self.sex_ed.setObjectName("sex_ed")
        self.bmi_ed = QtWidgets.QLineEdit(Form)
        self.bmi_ed.setGeometry(QtCore.QRect(360, 330, 231, 31))
        self.bmi_ed.setStyleSheet("background-color: rgb(229, 229, 229);\n"
"font: 11pt \"Times New Roman\";\n"
"color: rgb(6, 6, 6);")
        self.bmi_ed.setObjectName("bmi_ed")
        self.child_ed = QtWidgets.QLineEdit(Form)
        self.child_ed.setGeometry(QtCore.QRect(360, 390, 231, 31))
        self.child_ed.setStyleSheet("background-color: rgb(229, 229, 229);\n"
"font: 11pt \"Times New Roman\";\n"
"color: rgb(6, 6, 6);")
        self.child_ed.setObjectName("child_ed")
        self.smok_ed = QtWidgets.QLineEdit(Form)
        self.smok_ed.setGeometry(QtCore.QRect(360, 450, 231, 31))
        self.smok_ed.setStyleSheet("background-color: rgb(229, 229, 229);\n"
"font: 11pt \"Times New Roman\";\n"
"color: rgb(6, 6, 6);")
        self.smok_ed.setObjectName("smok_ed")
        self.reg_ed = QtWidgets.QLineEdit(Form)
        self.reg_ed.setGeometry(QtCore.QRect(360, 510, 231, 31))
        self.reg_ed.setStyleSheet("background-color: rgb(229, 229, 229);\n"
"font: 11pt \"Times New Roman\";\n"
"color: rgb(6, 6, 6);")
        self.reg_ed.setObjectName("reg_ed")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(400, 570, 141, 51))
        self.pushButton.setStyleSheet("color:  rgb(255, 255, 255);\n"
"font: 63 10pt \"Segoe UI Semibold\";\n"
"background-color: rgb(70, 0, 69);")
        self.pushButton.setObjectName("pushButton")
        self.result = QtWidgets.QLabel(Form)
        self.result.setGeometry(QtCore.QRect(460, 630, 371, 81))
        self.result.setStyleSheet("font: 14pt \"Rockwell\";\n"
"color: rgb(86, 9, 82);")
        self.result.setText("")
        self.result.setAlignment(QtCore.Qt.AlignCenter)
        self.result.setObjectName("result")
        
        self.pushButton.clicked.connect(self.predict)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def predict(self):
        age = self.age_ed.text()
        x1 = int(age)
        
        sex = self.sex_ed.text()
        if sex=="female":
            x2 = 0
        else:
            x2 = 1
        
        bmi = self.bmi_ed.text()
        x3 = float(bmi)
        
        child = self.child_ed.text()
        x4 = int(child)
        
        smok = self.smok_ed.text()
        if smok == "yes":
            x5 = 1
        else:
            x5 = 0
            
        reg = self.reg_ed.text()
        if reg == "southwest":
            x6 = 3
        elif reg == "southeast":
            x6 = 2
        elif reg == "northwest":
            x6 = 1
        else:
            x6 = 0
            
        #x6 = str(reg)
        
        print(x1,x2,x3,x4,x5,x6)
        
        import pandas as pd
        path = "D:/2022projects/Linear_MultipleRegression/Insurance/insurance.csv"
        data =  pd.read_csv(path)

        import sklearn 
        from sklearn.preprocessing import LabelEncoder

        le = LabelEncoder()
        data['sex_n'] = le.fit_transform(data['sex'])
        data['smoker_n'] = le.fit_transform(data['smoker'])
        data['region_n'] = le.fit_transform(data['region'])


        x = data.drop(['charges','sex','smoker','region'] , 'columns')
        y = data.charges
        print(x)

        from sklearn.model_selection import train_test_split
        from sklearn import linear_model
        x_train , x_test , y_train , y_test = train_test_split(x,y ,test_size=0.4)

        model = linear_model.LinearRegression() 
        model.fit(x_train , y_train)
        y_pred = model.predict(x_test)
        res = model.predict([[x1,x3,x4,x2,x5,x6]])
        res = str(res)
        self.result.setText(res)
        print("Prediction:",res)
        
        

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Insurance Charges Prediction"))
        self.label.setText(_translate("Form", "Insurance Charges Prediction"))
        self.label_2.setText(_translate("Form", "Age:"))
        self.label_3.setText(_translate("Form", "Sex:"))
        self.label_4.setText(_translate("Form", "BMI:"))
        self.label_5.setText(_translate("Form", "Children:"))
        self.label_6.setText(_translate("Form", "Smoker:"))
        self.label_7.setText(_translate("Form", "Region:"))
        self.label_8.setText(_translate("Form", "Insurance Charges:"))
        self.label_9.setText(_translate("Form", "ENTER THE BELOW DETAILS"))
        self.pushButton.setText(_translate("Form", "PREDICT"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# 19 0 27.9 0 1 3
# C:\Users\91998\AppData\Local\Temp\ipykernel_13856\867228289.py:183: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x = data.drop(['charges','sex','smoker','region'] , 'columns')
# C:\Users\91998\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
#       age     bmi  children  sex_n  smoker_n  region_n
# 0      19  27.900         0      0         1         3
# 1      18  33.770         1      1         0         2
# 2      28  33.000         3      1         0         2
# 3      33  22.705         0      1         0         1
# 4      32  28.880         0      1         0         1
# ...   ...     ...       ...    ...       ...       ...
# 1333   50  30.970         3      1         0         1
# 1334   18  31.920         0      0         0         0
# ...
